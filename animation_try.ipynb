# %%
import numpy as np
from scipy.fftpack import fft2, ifft2
import time as tm
import plotly.graph_objects as go

# %%
# Parameters
g = 9.81  # Gravity (m/s^2)
L1 = 8814e3  # Distance Tokyo to LA (m)
L2 = 4688e3  # Distance Tokyo to New Guinea (m)
Nx = 256  # Number of grid points in x
Ny = 256  # Number of grid points in y
dx = L1 / (Nx - 1)  # Grid spacing in x
dy = L2 / (Ny - 1)  # Grid spacing in y
x = np.linspace(0, L1, Nx)
y = np.linspace(0, L2, Ny)
X, Y = np.meshgrid(x, y)
dt = 10  # Time step (s) - adjust for stability
hours = 3
t_end = 3600 * hours  # Simulation time
time = np.arange(0, t_end, dt)
Nt = len(time)

# %%
# Depth function (average 4km, sinusoidal variation)
def depth(x, y):
    return 4000 * (1+np.sin(2 * np.pi * (x-2*L1) / (5*L1)) * np.cos(2 * np.pi * y / L2))

D = depth(X, Y)

response = input("Would you like to plot the depth? (y/n): ")
if response == 'y':
    fig = go.Figure(data=[go.Surface(z=-D, x=x, y=y)])
    fig.update_layout(title='Depth (m)', autosize=False, width=800, height=800)
    fig.show()

# %%
# Initial conditions
x0 = L1 / 2
y0 = L2 / 2
sigma = L1 / 50

# Initial displacement (Gaussian pulse)
def initial_displacement(x, y, x0, y0, sigma):
    return 2*np.exp(-(((x - x0)/3)**2 / (2 * sigma**2) + ((y - y0))**2 / (2 * sigma**2))) + 3*np.exp(-((x - L1+1.5e6)**2 / (2 * sigma**2) + ((y -y0))**2 / (2 * sigma**2)))

eta = initial_displacement(X, Y, x0, y0, sigma)
eta_t = np.zeros(eta.shape)  # Initial velocity

response = input("Would you like to plot the initial displacement? (y/n): ")
if response == 'y':
    fig = go.Figure(data=[go.Surface(z=-eta, x=x, y=y)])
    fig.update_layout(title='Initial Displacement (m)', autosize=False, width=800, height=800)
    fig.show()

# %%
# Wavenumbers
kx = 2 * np.pi * np.fft.fftfreq(Nx, d=dx)
ky = 2 * np.pi * np.fft.fftfreq(Ny, d=dy)
KX, KY = np.meshgrid(kx, ky)

# Create a list of frames for the animation
def generate_frames():
    global eta, eta_t, Nt, dt, KX, KY
    for i in range(Nt):
        # Spatial derivatives in Fourier space
        eta_hat = fft2(eta)
        eta_xx_hat = -(KX**2) * eta_hat  # Second derivative in x
        eta_yy_hat = -(KY**2) * eta_hat  # Second derivative in y

        # Inverse FFT to get derivatives in spatial domain
        eta_x_x = np.real(ifft2(eta_xx_hat))
        eta_y_y = np.real(ifft2(eta_yy_hat))

        # RK4 stages
        k1_eta = eta_t
        k1_eta_t = g * D * (eta_x_x + eta_y_y)

        eta_temp = eta + 0.5 * dt * k1_eta
        
        eta_temp_hat = fft2(eta_temp)

        eta_x_x_temp_hat = -(KX**2) * eta_temp_hat
        eta_y_y_temp_hat = -(KY**2) * eta_temp_hat

        eta_x_x_temp = np.real(ifft2(eta_x_x_temp_hat))
        eta_y_y_temp = np.real(ifft2(eta_y_y_temp_hat))

        k2_eta = eta_t + 0.5 * dt * k1_eta_t
        k2_eta_t = g * D * (eta_x_x_temp + eta_y_y_temp)

        eta_temp = eta + 0.5 * dt * k2_eta

        eta_temp_hat = fft2(eta_temp)

        eta_x_x_temp_hat = -(KX**2) * eta_temp_hat
        eta_y_y_temp_hat = -(KY**2) * eta_temp_hat

        eta_x_x_temp = np.real(ifft2(eta_x_x_temp_hat))
        eta_y_y_temp = np.real(ifft2(eta_y_y_temp_hat))

        k3_eta = eta_t + 0.5 * dt * k2_eta_t
        k3_eta_t = g * D * (eta_x_x_temp + eta_y_y_temp)

        eta_temp = eta + dt * k3_eta

        eta_temp_hat = fft2(eta_temp)

        eta_x_x_temp_hat = -(KX**2) * eta_temp_hat
        eta_y_y_temp_hat = -(KY**2) * eta_temp_hat

        eta_x_x_temp = np.real(ifft2(eta_x_x_temp_hat))
        eta_y_y_temp = np.real(ifft2(eta_y_y_temp_hat))

        k4_eta = eta_t + dt * k3_eta_t
        k4_eta_t = g * D * (eta_x_x_temp + eta_y_y_temp)

        # Update eta and eta_t
        eta = eta + (dt / 6) * (k1_eta + 2 * k2_eta + 2 * k3_eta + k4_eta)
        eta_t = eta_t + (dt / 6) * (k1_eta_t + 2 * k2_eta_t + 2 * k3_eta_t + k4_eta_t)
        yield go.Frame(data=[go.Surface(z=eta, x=X, y=Y, colorscale='bluered')])
        

# Create the initial figure
fig = go.Figure(
    data=[go.Surface(z=np.sin(X) * np.cos(Y), x=X, y=Y, colorscale='bluered')],
    layout=go.Layout(
        title='3D Surface Plot Animation',
        scene=dict(
            xaxis_title='X (m)',
            yaxis_title='Y (m)',
            zaxis_title='Displacement',
            zaxis=dict(range=[-1, 1])
        ),
        updatemenus=[{
            'buttons': [
                {
                    'args': [None, {'frame': {'duration': 50, 'redraw': True}, 'fromcurrent': True}],
                    'label': 'Play',
                    'method': 'animate'
                },
                {
                    'args': [[None], {'frame': {'duration': 0, 'redraw': True}, 'mode': 'immediate', 'transition': {'duration': 0}}],
                    'label': 'Pause',
                    'method': 'animate'
                }
            ],
            'direction': 'left',
            'pad': {'r': 10, 't': 87},
            'showactive': False,
            'type': 'buttons',
            'x': 0.1,
            'xanchor': 'right',
            'y': 0,
            'yanchor': 'top'
        }],
        sliders=[{
            'steps': [
                {'args': [[str(i)], {'frame': {'duration': 0, 'redraw': True}, 'mode': 'immediate', 'transition': {'duration': 0}}],
                 'label': str(i),
                 'method': 'animate'} for i in range(Nt)
            ],
            'x': 0.1,
            'len': 0.9,
            'xanchor': 'left',
            'yanchor': 'top',
            'pad': {'b': 10, 't': 50},
            'currentvalue': {
                'font': {'size': 20},
                'prefix': 'Frame:',
                'visible': True,
                'xanchor': 'right'
            },
            'transition': {'duration': 0, 'easing': 'linear'}
        }]
    ),
    frames=list(generate_frames())
)

# Save the animation as an HTML file
fig.write_html(f"3d_surface_animation_with_slider_{tm.time()}.html")

# Show the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 69
#      65         yield go.Frame(data=[go.Surface(z=eta, x=X, y=Y, colorscale='bluered')])
#      68 # Create the initial figure
# ---> 69 fig = go.Figure(
#      70     data=[go.Surface(z=np.sin(X) * np.cos(Y), x=X, y=Y, colorscale='bluered')],
#      71     layout=go.Layout(
#      72         title='3D Surface Plot Animation',
#      73         scene=dict(
#      74             xaxis_title='X (m)',
#      75             yaxis_title='Y (m)',
#      76             zaxis_title='Displacement',
#      77             zaxis=dict(range=[-1, 1])
#      78         ),
#      79         updatemenus=[{
#      80             'buttons': [
#      81                 {
#      82                     'args': [None, {'frame': {'duration': 50, 'redraw': True}, 'fromcurrent': True}],
#      83                     'label': 'Play',
#      84                     'method': 'animate'
#      85                 },
#      86                 {
#      87                     'args': [[None], {'frame': {'duration': 0, 'redraw': True}, 'mode': 'immediate', 'transition': {'duration': 0}}],
#      88                     'label': 'Pause',
#      89                     'method': 'animate'
#      90                 }
#      91             ],
#      92             'direction': 'left',
#      93             'pad': {'r': 10, 't': 87},
#      94             'showactive': False,
#      95             'type': 'buttons',
#      96             'x': 0.1,
#      97             'xanchor': 'right',
#      98             'y': 0,
#      99             'yanchor': 'top'
#     100         }],
#     101         sliders=[{
#     102             'steps': [
#     103                 {'args': [[str(i)], {'frame': {'duration': 0, 'redraw': True}, 'mode': 'immediate', 'transition': {'duration': 0}}],
#     104                  'label': str(i),
#     105                  'method': 'animate'} for i in range(Nt)
#     106             ],
#     107             'x': 0.1,
#     108             'len': 0.9,
#     109             'xanchor': 'left',
#     110             'yanchor': 'top',
#     111             'pad': {'b': 10, 't': 50},
#     112             'currentvalue': {
#     113                 'font': {'size': 20},
#     114                 'prefix': 'Frame:',
#     115                 'visible': True,
#     116                 'xanchor': 'right'
#     117             },
#     118             'transition': {'duration': 0, 'easing': 'linear'}
#     119         }]
#     120     ),
#     121     frames=list(generate_frames())
#     122 )
#     124 # Save the animation as an HTML file
#     125 fig.write_html(f"3d_surface_animation_with_slider_{tm.time()}.html")
#
# File ~/.local/lib/python3.10/site-packages/plotly/graph_objs/_figure.py:629, in Figure.__init__(self, data, layout, frames, skip_invalid, **kwargs)
#       5 def __init__(
#       6     self, data=None, layout=None, frames=None, skip_invalid=False, **kwargs
#       7 ):
#       8     """
#       9     Create a new :class:Figure instance
#      10
#    (...)
#     627         is invalid AND skip_invalid is False
#     628     """
# --> 629     super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/plotly/basedatatypes.py:592, in BaseFigure.__init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     589 self._frames_validator = FramesValidator()
#     591 # ### Import frames ###
# --> 592 self._frame_objs = self._frames_validator.validate_coerce(
#     593     frames, skip_invalid=skip_invalid
#     594 )
#     596 # Note: Because frames are not currently supported in the widget
#     597 # context, we don't need to follow the pattern above and create
#     598 # _frames and _frame_defaults properties and then reparent the
#    (...)
#     606 # Flag that indicates whether we're currently inside a batch_*()
#     607 # context
#     608 self._in_batch_mode = False
#
# File ~/.local/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:2566, in CompoundArrayValidator.validate_coerce(self, v, skip_invalid)
#    2564 for v_el in v:
#    2565     if isinstance(v_el, self.data_class):
# -> 2566         res.append(self.data_class(v_el))
#    2567     elif isinstance(v_el, dict):
#    2568         res.append(self.data_class(v_el, skip_invalid=skip_invalid))
#
# File ~/.local/lib/python3.10/site-packages/plotly/graph_objs/_frame.py:243, in Frame.__init__(self, arg, baseframe, data, group, layout, name, traces, **kwargs)
#     241 _v = data if data is not None else _v
#     242 if _v is not None:
# --> 243     self["data"] = _v
#     244 _v = arg.pop("group", None)
#     245 _v = group if group is not None else _v
#
# File ~/.local/lib/python3.10/site-packages/plotly/basedatatypes.py:4846, in BasePlotlyType.__setitem__(self, prop, value)
#    4844 # ### Handle compound array property ###
#    4845 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
# -> 4846     self._set_array_prop(prop, value)
#    4848 # ### Handle simple property ###
#    4849 else:
#    4850     self._set_prop(prop, value)
#
# File ~/.local/lib/python3.10/site-packages/plotly/basedatatypes.py:5327, in BasePlotlyType._set_array_prop(self, prop, val)
#    5324 # Import value
#    5325 # ------------
#    5326 validator = self._get_validator(prop)
# -> 5327 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5329 # Save deep copies of current and new states
#    5330 # ------------------------------------------
#    5331 curr_val = self._compound_array_props.get(prop, None)
#
# File ~/.local/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:2689, in BaseDataValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2687             invalid_els.append(v_el)
#    2688     else:
# -> 2689         trace = self.get_trace_class(trace_type)(
#    2690             skip_invalid=skip_invalid, _validate=_validate, **v_copy
#    2691         )
#    2692         res.append(trace)
#    2693 else:
#
# File ~/.local/lib/python3.10/site-packages/plotly/graph_objs/_surface.py:2549, in Surface.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, coloraxis, colorbar, colorscale, connectgaps, contours, customdata, customdatasrc, hidesurface, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legendgroup, legendgrouptitle, legendrank, legendwidth, lighting, lightposition, meta, metasrc, name, opacity, opacityscale, reversescale, scene, showlegend, showscale, stream, surfacecolor, surfacecolorsrc, text, textsrc, uid, uirevision, visible, x, xcalendar, xhoverformat, xsrc, y, ycalendar, yhoverformat, ysrc, z, zcalendar, zhoverformat, zsrc, **kwargs)
#    2547 _v = colorscale if colorscale is not None else _v
#    2548 if _v is not None:
# -> 2549     self["colorscale"] = _v
#    2550 _v = arg.pop("connectgaps", None)
#    2551 _v = connectgaps if connectgaps is not None else _v
#
# File ~/.local/lib/python3.10/site-packages/plotly/basedatatypes.py:4850, in BasePlotlyType.__setitem__(self, prop, value)
#    4846         self._set_array_prop(prop, value)
#    4848     # ### Handle simple property ###
#    4849     else:
# -> 4850         self._set_prop(prop, value)
#    4851 else:
#    4852     # Make sure properties dict is initialized
#    4853     self._init_props()
#
# File ~/.local/lib/python3.10/site-packages/plotly/basedatatypes.py:5189, in BasePlotlyType._set_prop(self, prop, val)
#    5186 validator = self._get_validator(prop)
#    5188 try:
# -> 5189     val = validator.validate_coerce(val)
#    5190 except ValueError as err:
#    5191     if self._skip_invalid:
#
# File ~/.local/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:1638, in ColorscaleValidator.validate_coerce(self, v)
#    1635             v_valid = True
#    1637             # Convert to list of lists
# -> 1638             v = [
#    1639                 [e[0], ColorValidator.perform_validate_coerce(e[1])] for e in v
#    1640             ]
#    1642 if not v_valid:
#    1643     self.raise_invalid_val(v)
#
# File ~/.local/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:1639, in <listcomp>(.0)
#    1635             v_valid = True
#    1637             # Convert to list of lists
#    1638             v = [
# -> 1639                 [e[0], ColorValidator.perform_validate_coerce(e[1])] for e in v
#    1640             ]
#    1642 if not v_valid:
#    1643     self.raise_invalid_val(v)
#
# File ~/.local/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:1437, in ColorValidator.perform_validate_coerce(v, allow_number)
#    1434 v_normalized = v.replace(" ", "").lower()
#    1436 # if ColorValidator.re_hex.fullmatch(v_normalized):
# -> 1437 if fullmatch(ColorValidator.re_hex, v_normalized):
#    1438     # valid hex color (e.g. #f34ab3)
#    1439     return v
#    1440 elif fullmatch(ColorValidator.re_rgb_etc, v_normalized):
#    1441     # elif ColorValidator.re_rgb_etc.fullmatch(v_normalized):
#    1442     # Valid rgb(a), hsl(a), hsv(a) color
#    1443     # (e.g. rgba(10, 234, 200, 50%)
#
# File ~/.local/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:20, in fullmatch(regex, string, flags)
#      18 def fullmatch(regex, string, flags=0):
#      19     """Emulate python-3.4 re.fullmatch()."""
# ---> 20     if "pattern" in dir(regex):
#      21         regex_string = regex.pattern
#      22     else:
#
# KeyboardInterrupt:
